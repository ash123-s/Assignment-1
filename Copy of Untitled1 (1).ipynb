# %%
l=["monkey","rooster","dog","pig","rat","ox","tiger","rabbit","dragon","snake","horse","sheep"]
year=int(input("enter year:\n"))
a=int(year%12)
print(l[a])
# Out:
# enter year:
# 2020
# rat

# %%
w= int(input("weight of goods :"))
d=int(input("distance :"))
if(d>=500):
  if(w>=100):
    print(int(d*5))
  elif(w>=10 and w<100):
    print(int(d*6))
  elif(w<10):
      print(int(d*7))
else:
  if(w>=100):
    print(int(d*8))
  else:
    print((d*5))
# Out:
# weight of goods :20
# distance :25
# 125

# %%
seat=int(input("select the seat:\n1.stalls\n2.circle\n3.upperclass\n4.box\nchoose the option number\n"))
payment=int(input("enter the mode of payment:\n1.cash\n2.credit\nchoose the option number\ns"))
amount=[625,750,850,1000]
if (payment==1):
      print("10% discunt")
      a=(amount[seat-1]*10)/100
      b=int(amount[seat-1]-a)
      print("amount to be paid: ",b)
else:
      print("5% discount")
      c=(amount[seat-1]*5)/100
      d=int(amount[seat-1]-c)
      print("mount to be paid:",d)
# Out:
# select the seat:
# 1.stalls
# 2.circle
# 3.upperclass
# 4.box
# choose the number
# 2
# enter the mode of payment:
# 1.cash
# 2.credit
# 1
# 10% discunt
# amount to be paid:  675

# %%
weight=int(input("weight of the water in kilograms:\n"))
intial=int(input("intial temperature of water:\n"))
final=int(input("final temprature of water:\n"))
energy=weight*(final-intial)*4184
print("energy in joules:\n",energy)
# Out:
# weight of the water in kilograms:
# 1
# intial temperature of water:
# 0
# final temprature of water:
# 100
# energy in joules:
#  418400

# %%
month=input("enter the month;\n")
if (month=="december"or month=="january" or month=="february"):
  print("winter")
elif (month=="march"or month=="april"or month=='may'):
  print("spring")
elif (month=='june'or month=="july"or month=="august"):
  print("summer")
elif (month=="septmber"or month=="ocotber"or month=="november"):
  print("autumn")
# Out:
# enter the month;
# ocober
# autumn

# %%
weight=float (input("enter the weight in pounds"))
height=float (input("enter thr height in inches"))
wkilo=weight*0.45359237
hemeter=height*0.0254
bmi=wkilo/(hemeter**2)
if (bmi<18.5):
  print("UNDERWEIGHT")
elif (bmi<=18.5 or bmi<25.0):
  print("NORMAL")
elif (bmi<=25.0 or bmi<30.0):
  print("OVERWEIGHT")
else:
  print("OBESE")
# Out:
# enter the weight in pounds187.393
# enter thr height in inches69.6
# OVERWEIGHT

# %%
num=int(input("enter a number between 100 and 1000 :: "))
rem=0
sum=0
if(num>100 and num<1000):
    while num>0:
        rem=num%10
        sum=sum+rem
        num=num//10
    print(sum)
else:
    print("the number entered is not in the range")
# Out:
# enter a number between 100 and 1000 :: 121
# 4

# %%
rem=0
for i in range(1,1000):
    n=i
    rev=0
    while n>0:
        rem=n%10
        rev=rev*10+rem
        n=n//10
    if i==rev:
        print(i)

# %%
rem=0
for i in range(1,1000):
    n=i
    rev=0
    while n>0:
        rem=n%10
        rev=rev+rem**3
        n=n//10
    if i==rev:
        print(i)

# %%
for i in range(1,100):
    if i%3==0 and i%5==0:
        print("fizz buzz")
    elif i%3==0:
        print("fizz")
    elif i%5==0:
        print("buzz")

# %%
h=int(input("enter height of the well :: "))
u=int(input("enter the meters spider climb up for each sstep :: "))
d=int(input("enter the meters the spider slips down for each step :: "))
s=0
t=0
p=0
while t<=h:
    t=t+u
    if(t<=h):
        t=t-d
    s=s+1
print(s)
